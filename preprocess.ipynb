# %% [markdown]
# # Tiền xử lý dữ liệu giá Macbook pro 14" m1 pro

# %% [markdown]
# ### Mô tả tập dữ liệu `macbook.csv`
#
# Tập dữ liệu `macbook.csv` chứa thông tin về các sản phẩm MacBook Pro 14" M1 Pro được thu thập từ trang web Chợ Tốt. Dưới đây là mô tả chi tiết về các cột trong tập dữ liệu:
#
# - **name**: Tên sản phẩm, bao gồm thông tin về dòng máy, cấu hình (RAM, ROM), màu sắc, và tình trạng.
# - **price**: Giá của sản phẩm (đơn vị: VNĐ).
# - **district**: Quận/huyện nơi sản phẩm được rao bán.
# - **date_crawl**: Thời gian thu thập dữ liệu (định dạng: YYYY-MM-DD HH:MM:SS).
# - **product_type**: Thông tin chi tiết về cấu hình sản phẩm, bao gồm loại chip, dung lượng RAM, ROM, và loại ổ cứng.
# - **time_since_posted**: Khoảng thời gian kể từ khi bài đăng được tạo (ví dụ: "8 giờ trước", "2 ngày trước").
# - **image_link**: Đường dẫn đến hình ảnh của sản phẩm.
# - **product_link**: Đường dẫn đến trang chi tiết của sản phẩm trên Chợ Tốt.
# - **page**: Số trang mà sản phẩm xuất hiện trong kết quả tìm kiếm.
# - **ram**: Dung lượng RAM của sản phẩm (đơn vị: GB).
# - **rom**: Dung lượng bộ nhớ trong (ROM) của sản phẩm (đơn vị: GB).
#
# Tập dữ liệu này được sử dụng để phân tích và xử lý thông tin về các sản phẩm MacBook Pro 14" M1 Pro, hỗ trợ việc so sánh giá cả, cấu hình, và các thông tin liên quan khác.

# %% [markdown]
# ## Đọc và khám phá dữ liệu

# %%
import pandas as pd

# Tiền xử lý dữ liệu giá macbook pro m1 pro ở chợ tốt
# Đọc dữ liệu từ file CSV macbooks.csv
df = pd.read_csv('macbooks.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   833 non-null    object
#  1   price                  833 non-null    object
#  2   district               833 non-null    object
#  3   date_crawl             833 non-null    object
#  4   product_type           833 non-null    object
#  5   time_since_date_crawl  833 non-null    object
#  6   image_link             833 non-null    object
#  7   product_link           833 non-null    object
#  8   page                   833 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 58.7+ KB

# %% [markdown]
# Dữ liệu không có giá trị null. Sạch sẽ nha

# %%
df.head()
# Out:
#                                                 name         price  \
# 0             Macbook Pro 14" M1 Pro 16/512 Gray 99%  22.500.000 đ
# 1   Macbook Pro 14 inch M1 Pro/16/512Gb đẹp keng Zin  24.990.000 đ
# 2    Macbook Pro 14 inch M1 Pro 32Gb 1TB 99% pin 94%  28.990.000 đ
# 3   Macbook Pro 14 inch M1 Pro 32/1TB Gray VN 98-99%  27.500.000 đ
# 4     Macbook Pro 14" M1 Pro 16/512 Gray 99% Pin cao  26.490.000 đ
#
#         district           date_crawl                    product_type  \
# 0  Quận Tân Bình  2025-04-29 01:54:33  Khác | 16 GB | 512 GB | SSD |
# 1   Quận Tân Phú  2025-04-29 01:54:33        Khác | 16 GB | 512 GB |
# 2  Quận Tân Bình  2025-04-29 01:54:33                         Unknown
# 3  Quận Tân Bình  2025-04-29 01:54:33                 32 GB | 1 TB |
# 4        Quận 10  2025-04-29 01:54:33  Khác | 16 GB | 512 GB | SSD |
#
#   time_since_date_crawl                                         image_link  \
# 0           9 giờ trước  https://cdn.chotot.com/9lpAwUMGCmGQSgynQRlQZRm...
# 1          16 giờ trước  https://cdn.chotot.com/L5c3e-nN58HNyKWuUC9gBcl...
# 2               hôm qua  https://cdn.chotot.com/i86MNxyO09GNVb-31k6pn2G...
# 3          15 giờ trước  https://cdn.chotot.com/OPD3ovnRn_bEpVrf0HYb1Ot...
# 4          2 ngày trước  https://cdn.chotot.com/6HaDV5GN5vQNDfObNltCCYF...
#
#                                         product_link  page
# 0  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# 1  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# 2  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# 3  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# 4  https://www.chotot.com/mua-ban-laptop-quan-10-...     1

# %% [markdown]
# ### Đọc qua thì có một vài vấn đề cần xử lý
# - Tên sản phẩm có những cái tên không phải là dòng Macbook Pro 14" M1 Pro
# --> (1) Xử lý theo Regex bình thường (2) Xử lý bằng Model AI (Mình chọn Regex vì nó đơn giản, nhanh)
# - Xử lý giá tiền (Ví dụ: 22.990.000 đ --> 22990000)
# - Chưa có thuộc tính để biết được Ram và Rom của máy bao nhiêu.
# --> Mình sẽ dựa vào Product_type để trích xuất ra.

# %% [markdown]
# ### Loại bỏ những sản phẩm không phải là Macbook Pro 14" M1 Pro

# %%
import re
def isMacbookProM1Pro14(text):
    text = text.lower()
    # Chỉ cần kiểm tra xem có chứa 'm1' và '14' trong text hay không
    if re.search(r'm1',text) and re.search(r'14',text):
        return True
    
    return False

# %%
# Lọc những dòng có liên quan đến macbook pro m1 pro 14
df = df[df['name'].apply(lambda x: isMacbookProM1Pro14(x))]

# %%
print(df.head(10))
df.shape
# Out:
#                                                 name         price  \
# 0             Macbook Pro 14" M1 Pro 16/512 Gray 99%  22.500.000 đ
# 1   Macbook Pro 14 inch M1 Pro/16/512Gb đẹp keng Zin  24.990.000 đ
# 2    Macbook Pro 14 inch M1 Pro 32Gb 1TB 99% pin 94%  28.990.000 đ
# 3   Macbook Pro 14 inch M1 Pro 32/1TB Gray VN 98-99%  27.500.000 đ
# 4     Macbook Pro 14" M1 Pro 16/512 Gray 99% Pin cao  26.490.000 đ
# 5         MacBook Pro 14" M1, 16GB, 1TB, Máy Đẹp sạc  28.900.000 đ
# 6                                 MACBOOK PRO 14" M1  21.900.000 đ
# 7   Macbook pro 14 inch M1 pro 32G RAM/1TB 99% gi...  31.990.000 đ
# 8                    Macbook pro m1 14” - 16/512 99%  24.000.000 đ
# 9          Macbook Pro 14" M1 Pro 16/512 Gray 99% VN  25.990.000 đ
#
#         district           date_crawl                           product_type  \
# 0  Quận Tân Bình  2025-04-29 01:54:33         Khác | 16 GB | 512 GB | SSD |
# 1   Quận Tân Phú  2025-04-29 01:54:33               Khác | 16 GB | 512 GB |
# 2  Quận Tân Bình  2025-04-29 01:54:33                                Unknown
# 3  Quận Tân Bình  2025-04-29 01:54:33                        32 GB | 1 TB |
# 4        Quận 10  2025-04-29 01:54:33         Khác | 16 GB | 512 GB | SSD |
# 5  Quận Tân Bình  2025-04-29 01:54:33  Intel Core i7 | 16 GB | 1 TB | SSD |
# 6        Quận 10  2025-04-29 01:54:33         Khác | 16 GB | 512 GB | SSD |
# 7  Quận Tân Bình  2025-04-29 01:54:33           Khác | 32 GB | 1 TB | SSD |
# 8   Quận Tân Phú  2025-04-29 01:54:33                16 GB | 512 GB | SSD |
# 9  Quận Tân Bình  2025-04-29 01:54:33                16 GB | 512 GB | SSD |
#
#   time_since_date_crawl                                         image_link  \
# 0           9 giờ trước  https://cdn.chotot.com/9lpAwUMGCmGQSgynQRlQZRm...
# 1          16 giờ trước  https://cdn.chotot.com/L5c3e-nN58HNyKWuUC9gBcl...
# 2               hôm qua  https://cdn.chotot.com/i86MNxyO09GNVb-31k6pn2G...
# 3          15 giờ trước  https://cdn.chotot.com/OPD3ovnRn_bEpVrf0HYb1Ot...
# 4          2 ngày trước  https://cdn.chotot.com/6HaDV5GN5vQNDfObNltCCYF...
# 5          2 ngày trước  https://cdn.chotot.com/zG9Yms9xjW1Nq1zu1QYaTDw...
# 6          4 ngày trước  https://cdn.chotot.com/IdYa0NubD2PXIFZ_dfWWHZP...
# 7               hôm qua  https://cdn.chotot.com/2y22bR5pNYfLrdMQPSw4RDl...
# 8          3 ngày trước  https://cdn.chotot.com/Loz3g-yLiTyC5dWAXZt31W5...
# 9          5 ngày trước  https://cdn.chotot.com/t9JIWrAjbjQ0NbiEUpzcSRK...
#
#                                         product_link  page
# 0  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# 1  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# 2  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# 3  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# 4  https://www.chotot.com/mua-ban-laptop-quan-10-...     1
# 5  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# 6  https://www.chotot.com/mua-ban-laptop-quan-10-...     1
# 7  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# 8  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# 9  https://www.chotot.com/mua-ban-laptop-quan-tan...     1
# (50, 9)

# %% [markdown]
# ### Chuyển đổi giá tiền

# %%
# Xử lý cột price
def extract_price(price_str):
    # Tìm tất cả các số trong chuỗi
    numbers = re.findall(r'\d+', price_str)
    # Ghép các số lại thành một chuỗi duy nhất
    return int(''.join(numbers)) if numbers else 0

# Áp dụng hàm extract_price cho cột price
df['price'] = df['price'].apply(extract_price)
# Chuyển đổi cột price thành kiểu số nguyên
df['price'] = df['price'].astype(int)

# %% [markdown]
# ### Phân loại dung lượng Ram cho mỗi máy

# %%
rams = {'16': 16, '32': 32, '64': 64}

# Tính toán ram dựa vào cột product_type
def extract_ram(product_type, name):
    for ram in rams:
        if re.search(ram, product_type) or re.search(ram, name):
            return rams[ram]
    return 0

# Áp dụng hàm extract_ram cho cột product_type và cột name
df['ram'] = df.apply(lambda row: extract_ram(row['product_type'], row['name']), axis=1)

# Chuyển đổi cột ram thành kiểu số nguyên
df['ram'] = df['ram'].astype(int)

# %% [markdown]
# ### Phân loại dung lượng Rom cho mỗi máy

# %%
roms = {'512': 512, '1 tb': 1024, '1tb': 1024, '512gb': 512}
    
# Tính toán rom dựa vào cột product_type
def extract_rom(product_type, name):
    # Tìm tất cả các số trong chuỗi
    for rom in roms:
        if re.search(rom, product_type.lower()) or re.search(rom, name.lower()):
            return roms[rom]
    return 0

# Áp dụng hàm extract_rom cho cột product_type và name
df['rom'] = df.apply(lambda row: extract_rom(row['product_type'], row['name']), axis=1)
# Chuyển đổi cột rom thành kiểu số nguyên
df['rom'] = df['rom'].astype(int)

# %%
df.head(20)
# Out:
#                                                  name     price  \
# 0              Macbook Pro 14" M1 Pro 16/512 Gray 99%  22500000
# 1    Macbook Pro 14 inch M1 Pro/16/512Gb đẹp keng Zin  24990000
# 2     Macbook Pro 14 inch M1 Pro 32Gb 1TB 99% pin 94%  28990000
# 3    Macbook Pro 14 inch M1 Pro 32/1TB Gray VN 98-99%  27500000
# 4      Macbook Pro 14" M1 Pro 16/512 Gray 99% Pin cao  26490000
# 5          MacBook Pro 14" M1, 16GB, 1TB, Máy Đẹp sạc  28900000
# 6                                  MACBOOK PRO 14" M1  21900000
# 7    Macbook pro 14 inch M1 pro 32G RAM/1TB 99% gi...  31990000
# 8                     Macbook pro m1 14” - 16/512 99%  24000000
# 9           Macbook Pro 14" M1 Pro 16/512 Gray 99% VN  25990000
# 10               Macbook Pro 14 inch M1 Pro /16/512Gb  20900000
# 11    Macbook Pro 14” M1 Pro 16/512 chính hãng VN 99%  25990000
# 12      Macbook Pro 14" M1 Pro 16/1TB Gray Care 09/25  27490000
# 13               Macbook Pro 14" M1 Pro 16/1TB bhh t9  27500000
# 14   Macbook pro m1 14” 2021 16g/512g sạc91 lần bh...  21000000
# 15   Macbook Pro 14" M1 Pro 16/1TB 10/16gpu Fullbo...  27490000
# 17   Macbook Pro 14" M1Pro/16Gb/1TB Gray Care+ 3/2025  27500000
# 18   Apple MacBook Pro 2021 14" M1Pro/16G/512GB li...  28900000
# 20                    MBPRO 14" M1/16/512 Fullbox 98%  23500000
# 21                 Macbook Pro 14” M1/16/512 Gray 99%  24900000
#
#            district           date_crawl  \
# 0     Quận Tân Bình  2025-04-29 01:54:33
# 1      Quận Tân Phú  2025-04-29 01:54:33
# 2     Quận Tân Bình  2025-04-29 01:54:33
# 3     Quận Tân Bình  2025-04-29 01:54:33
# 4           Quận 10  2025-04-29 01:54:33
# 5     Quận Tân Bình  2025-04-29 01:54:33
# 6           Quận 10  2025-04-29 01:54:33
# 7     Quận Tân Bình  2025-04-29 01:54:33
# 8      Quận Tân Phú  2025-04-29 01:54:33
# 9     Quận Tân Bình  2025-04-29 01:54:33
# 10     Quận Tân Phú  2025-04-29 01:54:33
# 11          Quận 10  2025-04-29 01:54:33
# 12    Quận Tân Bình  2025-04-29 01:54:33
# 13    Quận Tân Bình  2025-04-29 01:54:33
# 14           Quận 3  2025-04-29 01:54:33
# 15          Quận 10  2025-04-29 01:54:33
# 17  Quận Bình Thạnh  2025-04-29 01:54:33
# 18           Quận 1  2025-04-29 01:54:37
# 20  Quận Bình Thạnh  2025-04-29 01:54:37
# 21     Quận Tân Phú  2025-04-29 01:54:37
#
#                              product_type time_since_date_crawl  \
# 0          Khác | 16 GB | 512 GB | SSD |            9 giờ trước
# 1                Khác | 16 GB | 512 GB |           16 giờ trước
# 2                                 Unknown               hôm qua
# 3                         32 GB | 1 TB |           15 giờ trước
# 4          Khác | 16 GB | 512 GB | SSD |           2 ngày trước
# 5   Intel Core i7 | 16 GB | 1 TB | SSD |           2 ngày trước
# 6          Khác | 16 GB | 512 GB | SSD |           4 ngày trước
# 7            Khác | 32 GB | 1 TB | SSD |                hôm qua
# 8                 16 GB | 512 GB | SSD |           3 ngày trước
# 9                 16 GB | 512 GB | SSD |           5 ngày trước
# 10                      16 GB | 512 GB |           6 ngày trước
# 11         Khác | 16 GB | 512 GB | SSD |           5 ngày trước
# 12                  16 GB | 1 TB | SSD |           6 ngày trước
# 13           Khác | 16 GB | 1 TB | SSD |           6 ngày trước
# 14                                Unknown          5 ngày trước
# 15           Khác | 16 GB | 1 TB | SSD |           6 ngày trước
# 17           Khác | 16 GB | 1 TB | SSD |           7 ngày trước
# 18         Khác | 16 GB | 512 GB | SSD |           5 ngày trước
# 20         Khác | 16 GB | 512 GB | SSD |           7 ngày trước
# 21                16 GB | 512 GB | SSD |           1 tuần trước
#
#                                            image_link  \
# 0   https://cdn.chotot.com/9lpAwUMGCmGQSgynQRlQZRm...
# 1   https://cdn.chotot.com/L5c3e-nN58HNyKWuUC9gBcl...
# 2   https://cdn.chotot.com/i86MNxyO09GNVb-31k6pn2G...
# 3   https://cdn.chotot.com/OPD3ovnRn_bEpVrf0HYb1Ot...
# 4   https://cdn.chotot.com/6HaDV5GN5vQNDfObNltCCYF...
# 5   https://cdn.chotot.com/zG9Yms9xjW1Nq1zu1QYaTDw...
# 6   https://cdn.chotot.com/IdYa0NubD2PXIFZ_dfWWHZP...
# 7   https://cdn.chotot.com/2y22bR5pNYfLrdMQPSw4RDl...
# 8   https://cdn.chotot.com/Loz3g-yLiTyC5dWAXZt31W5...
# 9   https://cdn.chotot.com/t9JIWrAjbjQ0NbiEUpzcSRK...
# 10  https://cdn.chotot.com/lnkFt96mx460HY21bWtKaeL...
# 11  https://cdn.chotot.com/Lp7Oa9irK0GLpiklDgjAUhi...
# 12  https://cdn.chotot.com/CPhFaCbwCf0uBFTuH-yRiYb...
# 13  https://cdn.chotot.com/FRIaByDprYVDhTAhRniPI5c...
# 14  https://cdn.chotot.com/EzKo8WlvNCKnM2qIZtloD15...
# 15  https://cdn.chotot.com/HQOCxRLL615xuP0RQA2bMpK...
# 17  https://cdn.chotot.com/fgMK9PyXpbmbKAHClWReZEx...
# 18  https://cdn.chotot.com/LcU_w1ql_9s0O_528w8tG4v...
# 20  https://cdn.chotot.com/kYnjpoJZMo1QwMs4VrwBIfm...
# 21  https://cdn.chotot.com/sWoX_R1TTV81GmUW7ZXX2sY...
#
#                                          product_link  page  ram   rom
# 0   https://www.chotot.com/mua-ban-laptop-quan-tan...     1   16   512
# 1   https://www.chotot.com/mua-ban-laptop-quan-tan...     1   16   512
# 2   https://www.chotot.com/mua-ban-laptop-quan-tan...     1   32  1024
# 3   https://www.chotot.com/mua-ban-laptop-quan-tan...     1   32  1024
# 4   https://www.chotot.com/mua-ban-laptop-quan-10-...     1   16   512
# 5   https://www.chotot.com/mua-ban-laptop-quan-tan...     1   16  1024
# 6   https://www.chotot.com/mua-ban-laptop-quan-10-...     1   16   512
# 7   https://www.chotot.com/mua-ban-laptop-quan-tan...     1   32  1024
# 8   https://www.chotot.com/mua-ban-laptop-quan-tan...     1   16   512
# 9   https://www.chotot.com/mua-ban-laptop-quan-tan...     1   16   512
# 10  https://www.chotot.com/mua-ban-laptop-quan-tan...     1   16   512
# 11  https://www.chotot.com/mua-ban-laptop-quan-10-...     1   16   512
# 12  https://www.chotot.com/mua-ban-laptop-quan-tan...     1   16  1024
# 13  https://www.chotot.com/mua-ban-laptop-quan-tan...     1   16  1024
# 14  https://www.chotot.com/mua-ban-laptop-quan-3-t...     1   16   512
# 15  https://www.chotot.com/mua-ban-laptop-quan-10-...     1   16  1024
# 17  https://www.chotot.com/mua-ban-laptop-quan-bin...     1   16  1024
# 18  https://www.chotot.com/mua-ban-laptop-quan-1-t...     2   16   512
# 20  https://www.chotot.com/mua-ban-laptop-quan-bin...     2   16   512
# 21  https://www.chotot.com/mua-ban-laptop-quan-tan...     2   16   512

# %% [markdown]
# ### Xuất dữ liệu đã được làm sạch ra môt file macbook_pro_m1_pro_14.csv

# %%
print(df[df['ram'] == 0].head(10))
# Xóa các dòng có ram = 0
df = df[df['ram'] != 0]
# Xóa các dòng có rom = 0
df = df[df['rom'] != 0]
# Out:
# Empty DataFrame
# Columns: [name, price, district, date_crawl, product_type, time_since_date_crawl, image_link, product_link, page, ram, rom]
# Index: []

# %%
# lưu dữ liệu vào file csv
df.to_csv('macbook_pro_m1_pro_14.csv', index=False)
